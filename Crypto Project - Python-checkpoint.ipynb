# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

#NOTE:
# I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# Into the Anaconda Prompt to change this to allow to pull data
# Out:
# {'status': {'timestamp': '2024-04-15T18:32:22.238Z', 'error_code': 0, 'error_message': None, 'elapsed': 28, 'credit_count': 1, 'notice': None, 'total_count': 9681}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11005, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
#This normalizes the data and makes it all pretty in a dataframe

df=pd.json_normalize(data['data'])
df['timestamp']=pd.to_datetime('now')
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             11005
# 1    1027      Ethereum    ETH      ethereum              8810
# 2     825   Tether USDt   USDT        tether             82784
# 3    1839           BNB    BNB           bnb              2146
# 4    5426        Solana    SOL        solana               652
# 5    3408          USDC   USDC      usd-coin             18463
# 6      52           XRP    XRP           xrp              1299
# 7   11419       Toncoin    TON       toncoin               277
# 8      74      Dogecoin   DOGE      dogecoin               953
# 9    2010       Cardano    ADA       cardano              1139
# 10   5805     Avalanche   AVAX     avalanche               710
# 11   5994     Shiba Inu   SHIB     shiba-inu               791
# 12   1831  Bitcoin Cash    BCH  bitcoin-cash               879
# 13   1958          TRON    TRX          tron               970
# ...

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }
    
    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    df=pd.json_normalize(data['data'])
    df['timestamp']=pd.to_datetime('now')
    df
    
    if not os.path.isfile(r'C:\Users\dell\Documents\Python Scripts\API2.csv'):
        df.to_csv(r'C:\Users\dell\Documents\Python Scripts\API2.csv', header='column_names')
    else:
        df.to_csv(r'C:\Users\dell\Documents\Python Scripts\API2.csv', mode='a', header=False)

# %%
df=pd.read_csv(r'C:\Users\dell\Documents\Python Scripts\API2.csv')

# %%
df
# Out:
#      Unnamed: 0    id          name symbol          slug  num_market_pairs  \
# 0             0     1       Bitcoin    BTC       bitcoin             11005
# 1             1  1027      Ethereum    ETH      ethereum              8810
# 2             2   825   Tether USDt   USDT        tether             82796
# 3             3  1839           BNB    BNB           bnb              2146
# 4             4  5426        Solana    SOL        solana               652
# ..          ...   ...           ...    ...           ...               ...
# 115          10  5805     Avalanche   AVAX     avalanche               710
# 116          11  5994     Shiba Inu   SHIB     shiba-inu               791
# 117          12  1831  Bitcoin Cash    BCH  bitcoin-cash               879
# 118          13  1958          TRON    TRX          tron               970
# 119          14  6636      Polkadot    DOT  polkadot-new               741
#
#                    date_added  \
# 0    2010-07-13T00:00:00.000Z
# ...

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print("API runner completed")
    sleep(60)
exit()
# Out:
# API runner completed
# API runner completed
# API runner completed
# API runner completed
# API runner completed
# API runner completed
# API runner completed
# API runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 8
#       6     api_runner()
#       7     print("API runner completed")
# ----> 8     sleep(60)
#       9 exit()
#
# KeyboardInterrupt:

# %%
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             11005
# 1    1027      Ethereum    ETH      ethereum              8810
# 2     825   Tether USDt   USDT        tether             82796
# 3    1839           BNB    BNB           bnb              2146
# 4    5426        Solana    SOL        solana               652
# 5    3408          USDC   USDC      usd-coin             18464
# 6      52           XRP    XRP           xrp              1299
# 7   11419       Toncoin    TON       toncoin               277
# 8      74      Dogecoin   DOGE      dogecoin               953
# 9    2010       Cardano    ADA       cardano              1139
# 10   5805     Avalanche   AVAX     avalanche               710
# 11   5994     Shiba Inu   SHIB     shiba-inu               791
# 12   1831  Bitcoin Cash    BCH  bitcoin-cash               879
# 13   1958          TRON    TRX          tron               970
# ...

# %%
pd.set_option('display.float_format', lambda x: '%5f' % x)

# %%
df
# Out:
#      Unnamed: 0     id          name symbol          slug  num_market_pairs  \
# 0             0      1       Bitcoin    BTC       bitcoin             11005
# 1             1   1027      Ethereum    ETH      ethereum              8810
# 2             2    825   Tether USDt   USDT        tether             82796
# 3             3   1839           BNB    BNB           bnb              2146
# 4             4   5426        Solana    SOL        solana               652
# 5             5   3408          USDC   USDC      usd-coin             18464
# 6             6     52           XRP    XRP           xrp              1299
# 7             7  11419       Toncoin    TON       toncoin               277
# 8             8     74      Dogecoin   DOGE      dogecoin               953
# 9             9   2010       Cardano    ADA       cardano              1139
# 10           10   5805     Avalanche   AVAX     avalanche               710
# ...

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#               quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          0.397573                     -1.356200
# Ethereum                         0.752308                      0.733537
# Tether USDt                     -0.009564                      0.004762
# BNB                              0.467276                      0.920215
# Solana                           0.882533                     -3.147941
# USDC                             0.006351                      0.000336
# XRP                              0.945469                      1.515190
# Toncoin                          0.277737                      3.143591
# Dogecoin                        -0.606859                      5.256374
# Cardano                          1.563411                      1.222427
# Avalanche                        1.018162                     -0.855872
# Shiba Inu                        1.358616                      1.127314
# ...

# %%
df4=df3.stack()
df4
# Out:
# name
# Bitcoin       quote.USD.percent_change_1h      0.397573
#               quote.USD.percent_change_24h    -1.356200
#               quote.USD.percent_change_7d    -11.630280
#               quote.USD.percent_change_30d    -5.446671
#               quote.USD.percent_change_60d    22.190766
#               quote.USD.percent_change_90d    46.087268
# Ethereum      quote.USD.percent_change_1h      0.752308
#               quote.USD.percent_change_24h     0.733537
#               quote.USD.percent_change_7d    -16.025882
#               quote.USD.percent_change_30d   -13.723455
#               quote.USD.percent_change_60d     9.736327
#               quote.USD.percent_change_90d    19.871455
# Tether USDt   quote.USD.percent_change_1h     -0.009564
#               quote.USD.percent_change_24h     0.004762
#               quote.USD.percent_change_7d      0.040327
#               quote.USD.percent_change_30d     0.094953
#               quote.USD.percent_change_60d    -0.037693
# ...

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5=df4.to_frame(name='values')
df5
# Out:
#                                               values
# name
# Bitcoin      quote.USD.percent_change_1h    0.397573
#              quote.USD.percent_change_24h  -1.356200
#              quote.USD.percent_change_7d  -11.630280
#              quote.USD.percent_change_30d  -5.446671
#              quote.USD.percent_change_60d  22.190766
#              quote.USD.percent_change_90d  46.087268
# Ethereum     quote.USD.percent_change_1h    0.752308
#              quote.USD.percent_change_24h   0.733537
#              quote.USD.percent_change_7d  -16.025882
#              quote.USD.percent_change_30d -13.723455
#              quote.USD.percent_change_60d   9.736327
#              quote.USD.percent_change_90d  19.871455
# Tether USDt  quote.USD.percent_change_1h   -0.009564
#              quote.USD.percent_change_24h   0.004762
#              quote.USD.percent_change_7d    0.040327
#              quote.USD.percent_change_30d   0.094953
#              quote.USD.percent_change_60d  -0.037693
# ...

# %%
type(df5)
# Out:
# pandas.core.frame.DataFrame

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
index=pd.Index(range(90))

# %%
df6=df5.set_index(index)
df6
# Out:
#        values
# 0    0.397573
# 1   -1.356200
# 2  -11.630280
# 3   -5.446671
# 4   22.190766
# 5   46.087268
# 6    0.752308
# 7    0.733537
# 8  -16.025882
# 9  -13.723455
# 10   9.736327
# 11  19.871455
# 12  -0.009564
# 13   0.004762
# 14   0.040327
# 15   0.094953
# 16  -0.037693
# 17   0.032471
# 18   0.467276
# 19   0.920215
# 20  -5.572576
# 21  -4.817212
# 22  57.653821
# 23  76.091109
# 24   0.882533
# 25  -3.147941
# 26 -23.041605
# 27 -22.386183
# 28  21.488815
# 29  42.370051
# 30   0.006351
# 31   0.000336
# 32  -0.003098
# 33   0.003838
# 34   0.002956
# 35  -0.031400
# 36   0.945469
# 37   1.515190
# 38 -20.071421
# 39 -17.777552
# 40 -10.177412
# 41 -13.942661
# 42   0.277737
# 43   3.143591
# 44   6.921570
# 45  90.241846
# 46 203.478478
# 47 175.158214
# 48  -0.606859
# 49   5.256374
# 50 -20.525913
# 51  12.870367
# 52  87.726509
# 53  95.858226
# 54   1.563411
# 55   1.222427
# 56 -25.562250
# 57 -31.118326
# 58 -23.987724
# 59 -15.545486
# 60   1.018162
# ...

# %%
df6=df5.reset_index()

# %%
df6
# Out:
#             name                       level_1     values
# 0        Bitcoin   quote.USD.percent_change_1h   0.397573
# 1        Bitcoin  quote.USD.percent_change_24h  -1.356200
# 2        Bitcoin   quote.USD.percent_change_7d -11.630280
# 3        Bitcoin  quote.USD.percent_change_30d  -5.446671
# 4        Bitcoin  quote.USD.percent_change_60d  22.190766
# 5        Bitcoin  quote.USD.percent_change_90d  46.087268
# 6       Ethereum   quote.USD.percent_change_1h   0.752308
# 7       Ethereum  quote.USD.percent_change_24h   0.733537
# 8       Ethereum   quote.USD.percent_change_7d -16.025882
# 9       Ethereum  quote.USD.percent_change_30d -13.723455
# 10      Ethereum  quote.USD.percent_change_60d   9.736327
# 11      Ethereum  quote.USD.percent_change_90d  19.871455
# 12   Tether USDt   quote.USD.percent_change_1h  -0.009564
# 13   Tether USDt  quote.USD.percent_change_24h   0.004762
# 14   Tether USDt   quote.USD.percent_change_7d   0.040327
# ...

# %%
df7=df6.rename(columns={'level_1':'Percent of Charges'})

# %%
df7
# Out:
#             name            Percent of Charges     values
# 0        Bitcoin   quote.USD.percent_change_1h   0.397573
# 1        Bitcoin  quote.USD.percent_change_24h  -1.356200
# 2        Bitcoin   quote.USD.percent_change_7d -11.630280
# 3        Bitcoin  quote.USD.percent_change_30d  -5.446671
# 4        Bitcoin  quote.USD.percent_change_60d  22.190766
# 5        Bitcoin  quote.USD.percent_change_90d  46.087268
# 6       Ethereum   quote.USD.percent_change_1h   0.752308
# 7       Ethereum  quote.USD.percent_change_24h   0.733537
# 8       Ethereum   quote.USD.percent_change_7d -16.025882
# 9       Ethereum  quote.USD.percent_change_30d -13.723455
# 10      Ethereum  quote.USD.percent_change_60d   9.736327
# 11      Ethereum  quote.USD.percent_change_90d  19.871455
# 12   Tether USDt   quote.USD.percent_change_1h  -0.009564
# 13   Tether USDt  quote.USD.percent_change_24h   0.004762
# 14   Tether USDt   quote.USD.percent_change_7d   0.040327
# ...

# %%
df7['Percent of Charges']=df7['Percent of Charges'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['1h','24h','7d','30d','60d','90d'])
df7
# Out:
#             name Percent of Charges     values
# 0        Bitcoin                 1h   0.397573
# 1        Bitcoin                24h  -1.356200
# 2        Bitcoin                 7d -11.630280
# 3        Bitcoin                30d  -5.446671
# 4        Bitcoin                60d  22.190766
# 5        Bitcoin                90d  46.087268
# 6       Ethereum                 1h   0.752308
# 7       Ethereum                24h   0.733537
# 8       Ethereum                 7d -16.025882
# 9       Ethereum                30d -13.723455
# 10      Ethereum                60d   9.736327
# 11      Ethereum                90d  19.871455
# 12   Tether USDt                 1h  -0.009564
# 13   Tether USDt                24h   0.004762
# 14   Tether USDt                 7d   0.040327
# 15   Tether USDt                30d   0.094953
# 16   Tether USDt                60d  -0.037693
# 17   Tether USDt                90d   0.032471
# 18           BNB                 1h   0.467276
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='Percent of Charges',y='values',hue='name',data=df7,kind='point')
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df10=df[['name','quote.USD.price','timestamp']]
df10
# Out:
#              name  quote.USD.price                   timestamp
# 0         Bitcoin     63351.150122  2024-04-16 01:50:14.529435
# 1        Ethereum      3104.689956  2024-04-16 01:50:14.529435
# 2     Tether USDt         1.000379  2024-04-16 01:50:14.529435
# 3             BNB       557.197633  2024-04-16 01:50:14.529435
# 4          Solana       138.760031  2024-04-16 01:50:14.529435
# 5            USDC         0.999944  2024-04-16 01:50:14.529435
# 6             XRP         0.498082  2024-04-16 01:50:14.529435
# 7         Toncoin         6.737556  2024-04-16 01:50:14.529435
# 8        Dogecoin         0.160289  2024-04-16 01:50:14.529435
# 9         Cardano         0.458334  2024-04-16 01:50:14.529435
# 10      Avalanche        35.493160  2024-04-16 01:50:14.529435
# 11      Shiba Inu         0.000022  2024-04-16 01:50:14.529435
# 12   Bitcoin Cash       505.595011  2024-04-16 01:50:14.529435
# 13           TRON         0.111658  2024-04-16 01:50:14.529435
# ...
